# %%
# %cd contador_palabras
# Out:
# [Errno 2] No such file or directory: 'contador_palabras'
# /media/notebooks/contador_palabras

# %%
# !ls *.txt -l
# Out:
# -rwxrwxrwx 1 root root 2141519 Nov 13 09:20 quijote.txt

# %%
# !hdfs dfs -mkdir /contar_palabras
# Out:
# mkdir: `/contar_palabras': File exists

# %%
# !hdfs dfs -put ./quijote.txt /contar_palabras/quijote.txt
# Out:
# put: `/contar_palabras/quijote.txt': File exists

# %%
# !hdfs dfs -ls /contar_palabras
# Out:
# Found 1 items
# -rw-r--r--   3 root supergroup    2141519 2025-11-13 09:22 /contar_palabras/quijote.txt

# %%
# %%writefile mapper.py
#!/usr/bin/env python3
import sys
 
for line in sys.stdin:
    line = line.strip()
    words = line.split()
    for word in words:
        print(f"{word}\t1")
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/env python3
import sys
 
current_word = None
current_count = 0
 
for line in sys.stdin:
    word, count = line.strip().split("\t", 1)
    count = int(count)
 
    if current_word == word:
        current_count += count
    else:
        if current_word:
            print(f"{current_word}\t{current_count}")
        current_word = word
        current_count = count
 
if current_word:
    print(f"{current_word}\t{current_count}")
# Out:
# Overwriting reducer.py

# %%
# !cat quijote.txt | python3 mapper.py | sort | python3 reducer.py
# Out:
# Traceback (most recent call last):
#   File "/media/notebooks/contador_palabras/reducer.py", line 8, in <module>
#     word, count = line.strip().split("\t", 1)
# ValueError: not enough values to unpack (expected 2, got 1)
# sort: write failed: 'standard output': Broken pipe
# sort: write error
